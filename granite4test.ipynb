# %% [markdown]
# <a href="https://colab.research.google.com/github/anandchauhan21/IBM_Granite_llm/blob/main/granite4test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q transformers accelerate bitsandbytes torch
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 18.0 MB/s eta 0:00:00

# %% [markdown]
# Granite 4.0 Micro on Google Colab (Free Tier)
#
# 🔹 1. Set your Colab runtime
# In Colab:
#
# Runtime → Change runtime type
#
# SettingValueHardware AcceleratorGPUGPU TypeT4 (default)
#
# Click Save

# %% [markdown]
# V4 gpu

# %%
# !pip install -q transformers accelerate torch

import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

model_id = "ibm-granite/granite-4.0-micro"

tokenizer = AutoTokenizer.from_pretrained(model_id)

model = AutoModelForCausalLM.from_pretrained(
    model_id,
    torch_dtype=torch.float16,
    device_map="auto",
    trust_remote_code=True
)

messages = [
    {"role": "user", "content": "Who are you?"}
]

inputs = tokenizer.apply_chat_template(
    messages,
    add_generation_prompt=True,
    return_tensors="pt"
).to(model.device)

outputs = model.generate(inputs, max_new_tokens=40)

print(tokenizer.decode(outputs[0][inputs.shape[-1]:], skip_special_tokens=True))
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/579 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/1.89G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# I am an AI assistant designed to provide accurate, safe, and professional responses to your inquiries. I'm here to help you with a wide range of tasks, from answering questions to providing information and assistance

# %%
def chat_with_granite():
    history = []

    while True:
        user_input = input("You: ")

        if user_input.lower() in ["exit", "quit"]:
            break

        history.append({"role": "user", "content": user_input})

        inputs = tokenizer.apply_chat_template(
            history,
            add_generation_prompt=True,
            return_tensors="pt"
        ).to(model.device)

        outputs = model.generate(inputs, max_new_tokens=200)

        reply = tokenizer.decode(outputs[0][inputs.shape[-1]:], skip_special_tokens=True)

        print("Granite:", reply)

        history.append({"role": "assistant", "content": reply})

# %%
chat_with_granite()
# Out:
# You: Explain quantum computing in simple terms.
# Granite: Quantum computing is a type of computing that uses the principles of quantum mechanics to process information. Unlike traditional computers that use bits (0s and 1s) to process information, quantum computers use quantum bits or "qubits".
#
# A key feature of qubits is that they can be both 0 and 1 at the same time, thanks to a property called superposition. This allows quantum computers to process a vast number of possibilities all at once.
#
# Another important principle is entanglement, where qubits become interconnected and the state of one can instantly affect the state of another, no matter the distance between them. This can be used to perform complex calculations much faster than traditional computers.
#
# In simple terms, quantum computing is like having a supercharged computer that can solve complex problems much faster than traditional computers by taking advantage of the strange and fascinating rules of quantum mechanics.
# You: Write a Python script to read a CSV and find the top 5 rows by revenue.
# Granite: Here is a simple Python script that uses the pandas library to read a CSV file and find the top 5 rows by revenue. This script assumes that the CSV file has a column named 'Revenue'.
#
# ```python
# import pandas as pd
#
# # Load the CSV file
# df = pd.read_csv('your_file.csv')
#
# # Sort the dataframe by 'Revenue' in descending order
# df_sorted = df.sort_values(by='Revenue', ascending=False)
#
# # Get the top 5 rows
# top_5_rows = df_sorted.head(5)
#
# # Print the top 5 rows
# print(top_5_rows)
# ```
#
# Please replace `'your_file.csv'` with the path to your actual CSV file. This script will print the top 5 rows with the highest revenue.
#
# Note: This script requires the pandas library. If it's not installed in your Python environment, you can install it using pip:
#
# ```python
# pip install pandas
# ```
# You: Summarize the benefits of using AI in supply chain management.
# Granite: Artificial Intelligence (AI) in supply chain management offers several benefits:
#
# 1. **Improved Efficiency**: AI can automate routine tasks, reducing the time and resources needed for these operations. This leads to increased efficiency and productivity.
#
# 2. **Predictive Analytics**: AI can analyze historical data to predict future trends and patterns. This can help in forecasting demand, managing inventory, and planning production.
#
# 3. **Enhanced Decision Making**: AI can provide real-time data and insights, enabling better decision-making. This can lead to improved operational efficiency and cost savings.
#
# 4. **Risk Management**: AI can help identify potential risks in the supply chain, such as delays or disruptions, and suggest mitigation strategies.
#
# 5. **Improved Customer Satisfaction**: By ensuring timely delivery and accurate inventory levels, AI can help improve customer satisfaction and loyalty.
#
# 6. **Cost Reduction**: AI can help reduce costs by optimizing routes, reducing waste, and improving inventory management.
#
# 7. **Increased Agility**: AI can help supply chains become more agile
# You: exit
